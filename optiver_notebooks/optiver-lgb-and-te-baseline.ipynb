# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/VIX.png/440px-VIX.png)
#
# This is yet another starter using lightGBM.
#
# **Don't just fork this notebook and publish**, which just confuses people. In case you were to publish a very similar notebook, please cite this notebook.
#
# As this notebook was created for new participants to get started easily, I tried to keep it as simple as possible.
#
# The basic strategy employed in this notebook includes:
#
# - Target Encoding (TE): Simply using the past volatility can predicts the future one very well due to the high autocorrelation nature of the volatility signal.
# - Aggregation by multiple keys: not only stock_id x time_id, but also stock_id and time_id, separately (to let our model know the nature of those keys).
# - Multithreads processing for feature engineering: many features are made on a stock_id x time_id basis, so we might want to accelerate the process.
# - LightGBM with the inverse weight of the square of the target: the evaluation metric is the root mean square percentage error, so we use RMSE as the objective function with the inverse weighting of  (square of) the target.
#
# You can also find its inference only notebook (for faster submission): [[Optiver] LGB and TE baseline (inference)](https://www.kaggle.com/code1110/optiver-lgb-and-te-baseline-inference)
#
# So let's get the ball rolling!

# %%
DEBUG = False
MODE = 'TRAIN'
# MODE = 'INFERENCE'
MODEL_DIR = '../data/'

# %% [markdown]
# # Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import gc
import pathlib
from tqdm.auto import tqdm
import json
from multiprocessing import Pool, cpu_count
import time
import requests as re
from datetime import datetime
from dateutil.relativedelta import relativedelta, FR

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import glob
import os
from sklearn import model_selection
import joblib
import lightgbm as lgb

# visualize
import matplotlib.pyplot as plt
import matplotlib.style as style
from matplotlib_venn import venn2, venn3
import seaborn as sns
from matplotlib import pyplot
from matplotlib.ticker import ScalarFormatter
sns.set_context("talk")
style.use('seaborn-colorblind')

import warnings
warnings.simplefilter('ignore')

pd.get_option("display.max_columns")
# Out:
# 20

# %% [markdown]
# # Config

# %%
class CFG:
    INPUT_DIR = '../data/'
    OUTPUT_DIR = './'
    N_SPLITS = 10
    SEED = 46

# %%
# Logging is always nice for your experiment:)
def init_logger(log_file='train.log'):
    from logging import getLogger, INFO, FileHandler,  Formatter,  StreamHandler
    logger = getLogger(__name__)
    logger.setLevel(INFO)
    handler1 = StreamHandler()
    handler1.setFormatter(Formatter("%(message)s"))
    handler2 = FileHandler(filename=log_file)
    handler2.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler1)
    logger.addHandler(handler2)
    return logger

logger = init_logger(log_file=f'{CFG.OUTPUT_DIR}/baseline.log')
logger.info(f'Start Logging...')
# Out:
# Start Logging...
# Start Logging...

# %% [markdown]
# # Load data
#
# Data description found in :
#
# https://www.kaggle.com/c/optiver-realized-volatility-prediction/data

# %% [markdown]
# ## Train, test, and sample submission
# train.csv The ground truth values for the training set.
#
# stock_id - Same as above, but since this is a csv the column will load as an integer instead of categorical.
# time_id - Same as above.
# target - The realized volatility computed over the 10 minute window following the feature data under the same stock/time_id. There is no overlap between feature and target data. You can find more info in our tutorial notebook.
# test.csv Provides the mapping between the other data files and the submission file. As with other test files, most of the data is only available to your notebook upon submission with just the first few rows available for download.
#
# stock_id - Same as above.
# time_id - Same as above.
# row_id - Unique identifier for the submission row. There is one row for each existing time ID/stock ID pair. Each time window is not necessarily containing every individual stock.
# sample_submission.csv - A sample submission file in the correct format.
#
# row_id - Same as in test.csv.
# target - Same definition as in train.csv. The benchmark is using the median target value from train.csv.

# %%
train = pd.read_csv(os.path.join(CFG.INPUT_DIR, 'train.csv'))

logger.info('Train data: {}'.format(train.shape))
train.head()
# Out:
# Train data: (428932, 3)
# Train data: (428932, 3)
#    stock_id  time_id    target
# 0         0        5  0.004136
# 1         0       11  0.001445
# 2         0       16  0.002168
# 3         0       31  0.002195
# 4         0       62  0.001747

# %%
train['stock_id'].value_counts()
# Out:
# 126    3830
# 46     3830
# 33     3830
# 34     3830
# 35     3830
#        ...
# 13     3829
# 75     3829
# 100    3829
# 80     3820
# 38     3815
# Name: stock_id, Length: 112, dtype: int64

# %%
train['time_id'].value_counts()
# Out:
# 22517    112
# 31320    112
# 1879     112
# 12114    112
# 7764     112
#         ...
# 10765    111
# 6172     111
# 13735    111
# 6696     111
# 24161    111
# Name: time_id, Length: 3830, dtype: int64

# %%
train['target'].hist(bins=100)

# %%
fig, ax = plt.subplots(16, 7, figsize=(20, 60))
ax = ax.flatten()

for i, stock_id in tqdm(enumerate(train['stock_id'].unique())):
    ax[i].hist(train.query('stock_id == @stock_id')['target'], bins=100)
    ax[i].set_title(stock_id)
plt.tight_layout()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
test = pd.read_csv(os.path.join(CFG.INPUT_DIR, 'test.csv'))

logger.info('Test data: {}'.format(test.shape))
test.head()
# Out:
# Test data: (3, 3)
#    stock_id  time_id row_id
# 0         0        4    0-4
# 1         0       32   0-32
# 2         0       34   0-34

# %%
venn2([
    set(train['time_id'])
    , set(test['time_id'])
])

# %%
ss = pd.read_csv(os.path.join(CFG.INPUT_DIR, 'sample_submission.csv'))

logger.info('Sample submission: {}'.format(ss.shape))
ss.head()
# Out:
# Sample submission: (3, 2)
#   row_id    target
# 0    0-4  0.003048
# 1   0-32  0.003048
# 2   0-34  0.003048

# %% [markdown]
# ## Book

# %% [markdown]
# book_[train/test].parquet A parquet file partitioned by stock_id. Provides order book data on the most competitive buy and sell orders entered into the market. The top two levels of the book are shared. The first level of the book will be more competitive in price terms, it will then receive execution priority over the second level.
#
# stock_id - ID code for the stock. Not all stock IDs exist in every time bucket. Parquet coerces this column to the categorical data type when loaded; you may wish to convert it to int8.
# time_id - ID code for the time bucket. Time IDs are not necessarily sequential but are consistent across all stocks.
# seconds_in_bucket - Number of seconds from the start of the bucket, always starting from 0.
# bid_price[1/2] - Normalized prices of the most/second most competitive buy level.
# ask_price[1/2] - Normalized prices of the most/second most competitive sell level.
# bid_size[1/2] - The number of shares on the most/second most competitive buy level.
# ask_size[1/2] - The number of shares on the most/second most competitive sell level.
#
# ## Trade
#
# trade_[train/test].parquet A parquet file partitioned by stock_id. Contains data on trades that actually executed. Usually, in the market, there are more passive buy/sell intention updates (book updates) than actual trades, therefore one may expect this file to be more sparse than the order book.
#
# stock_id - Same as above.
# time_id - Same as above.
# seconds_in_bucket - Same as above. Note that since trade and book data are taken from the same time window and trade data is more sparse in general, this field is not necessarily starting from 0.
# price - The average price of executed transactions happening in one second. Prices have been normalized and the average has been weighted by the number of shares traded in each transaction.
# size - The sum number of shares traded.
# order_count - The number of unique trade orders taking place.

# %%
train_book_stocks = os.listdir(os.path.join(CFG.INPUT_DIR, 'book_train.parquet'))

if DEBUG:
    logger.info('Debug mode: using 3 stocks only')
    train_book_stocks = train_book_stocks[:3]

logger.info('{:,} train book stocks: {}'.format(len(train_book_stocks), train_book_stocks))
# Out:
# 112 train book stocks: ['stock_id=97', 'stock_id=43', 'stock_id=21', 'stock_id=72', 'stock_id=4', 'stock_id=112', 'stock_id=22', 'stock_id=105', 'stock_id=116', 'stock_id=63', 'stock_id=14', 'stock_id=87', 'stock_id=122', 'stock_id=59', 'stock_id=113', 'stock_id=23', 'stock_id=38', 'stock_id=76', 'stock_id=125', 'stock_id=15', 'stock_id=67', 'stock_id=27', 'stock_id=30', 'stock_id=1', 'stock_id=66', 'stock_id=96', 'stock_id=9', 'stock_id=13', 'stock_id=18', 'stock_id=50', 'stock_id=32', 'stock_id=95', 'stock_id=110', 'stock_id=101', 'stock_id=114', 'stock_id=98', 'stock_id=118', 'stock_id=82', 'stock_id=19', 'stock_id=5', 'stock_id=70', 'stock_id=58', 'stock_id=108', 'stock_id=75', 'stock_id=2', 'stock_id=62', 'stock_id=0', 'stock_id=42', 'stock_id=83', 'stock_id=40', 'stock_id=81', 'stock_id=26', 'stock_id=61', 'stock_id=78', 'stock_id=8', 'stock_id=104', 'stock_id=34', 'stock_id=80', 'stock_id=124', 'stock_id=35', 'stock_id=111', 'stock_id=77', 'stock_id=44', 'stock_id=16', 'stock_id=93', 'stock_id=10', 'stock_id=64', 'stock_id=90', 'stock_id=107', 'stock_id=68', 'stock_id=11', 'stock_id=85', 'stock_id=123', 'stock_id=126', 'stock_id=109', 'stock_id=103', 'stock_id=36', 'stock_id=20', 'stock_id=52', 'stock_id=51', 'stock_id=39', 'stock_id=41', 'stock_id=17', 'stock_id=74', 'stock_id=28', 'stock_id=99', 'stock_id=86', 'stock_id=55', 'stock_id=120', 'stock_id=69', 'stock_id=7', 'stock_id=53', 'stock_id=46', 'stock_id=56', 'stock_id=31', 'stock_id=33', 'stock_id=88', 'stock_id=102', 'stock_id=60', 'stock_id=3', 'stock_id=119', 'stock_id=29', 'stock_id=73', 'stock_id=94', 'stock_id=100', 'stock_id=89', 'stock_id=84', 'stock_id=47', 'stock_id=115', 'stock_id=37', 'stock_id=48', 'stock_id=6']

# %%
# load stock_id=0
def load_book(stock_id=0, data_type='train'):
    """
    load parquest book data for given stock_id
    """
    book_df = pd.read_parquet(os.path.join(CFG.INPUT_DIR, f'book_{data_type}.parquet/stock_id={stock_id}'))
    book_df['stock_id'] = stock_id
    book_df['stock_id'] = book_df['stock_id'].astype(np.int8)
    
    return book_df

def load_trade(stock_id=0, data_type='train'):
    """
    load parquest trade data for given stock_id
    """
    trade_df = pd.read_parquet(os.path.join(CFG.INPUT_DIR, f'trade_{data_type}.parquet/stock_id={stock_id}'))
    trade_df['stock_id'] = stock_id
    trade_df['stock_id'] = trade_df['stock_id'].astype(np.int8)
    
    return trade_df

book0 = load_book(0)
logger.info('Book data of stock id = 1: {}'.format(book0.shape))
book0.head()
# Out:
# Book data of stock id = 1: (917553, 11)
#    time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0        5                  0    1.001422    1.002301     1.00137    1.002353
# 1        5                  1    1.001422    1.002301     1.00137    1.002353
# 2        5                  5    1.001422    1.002301     1.00137    1.002405
# 3        5                  6    1.001422    1.002301     1.00137    1.002405
# 4        5                  7    1.001422    1.002301     1.00137    1.002405
#
#    bid_size1  ask_size1  bid_size2  ask_size2  stock_id
# 0          3        226          2        100         0
# 1          3        100          2        100         0
# 2          3        100          2        100         0
# 3          3        126          2        100         0
# 4          3        126          2        100         0

# %%
book0.tail()
# Out:
#         time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 917548    32767                568    0.998275    0.998754    0.997796
# 917549    32767                569    0.998275    0.998754    0.997892
# 917550    32767                571    0.998275    0.998754    0.997892
# 917551    32767                572    0.998275    0.998754    0.997892
# 917552    32767                582    0.998275    0.998754    0.998179
#
#         ask_price2  bid_size1  ask_size1  bid_size2  ask_size2  stock_id
# 917548    0.998946         90         90         48         28         0
# 917549    0.998946         91         90        200         28         0
# 917550    0.998946         91         90        100         28         0
# 917551    0.998946         92         90        100         28         0
# 917552    0.998946         92         90         26         28         0

# %%
trade0 = load_trade(0)
logger.info('Book data of stock id = 1: {}'.format(trade0.shape))
trade0.head()
# Out:
# Book data of stock id = 1: (123443, 6)
#    time_id  seconds_in_bucket     price  size  order_count  stock_id
# 0        5                 21  1.002301   326           12         0
# 1        5                 46  1.002778   128            4         0
# 2        5                 50  1.002818    55            1         0
# 3        5                 57  1.003155   121            5         0
# 4        5                 68  1.003646     4            1         0

# %%
trade0.tail()
# Out:
#         time_id  seconds_in_bucket     price  size  order_count  stock_id
# 123438    32767                471  0.998659   200            3         0
# 123439    32767                517  0.998515    90            1         0
# 123440    32767                523  0.998563     1            1         0
# 123441    32767                542  0.998803    90            4         0
# 123442    32767                567  0.998547   300            3         0

# %%
book_df = book0.merge(
    trade0
    , how='outer'
    , on=['time_id', 'stock_id', 'seconds_in_bucket']
)

print(book_df.shape)
book_df.head()
# Out:
# (917553, 14)
#    time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0        5                  0    1.001422    1.002301     1.00137    1.002353
# 1        5                  1    1.001422    1.002301     1.00137    1.002353
# 2        5                  5    1.001422    1.002301     1.00137    1.002405
# 3        5                  6    1.001422    1.002301     1.00137    1.002405
# 4        5                  7    1.001422    1.002301     1.00137    1.002405
#
#    bid_size1  ask_size1  bid_size2  ask_size2  stock_id  price  size  \
# 0          3        226          2        100         0    NaN   NaN
# 1          3        100          2        100         0    NaN   NaN
# 2          3        100          2        100         0    NaN   NaN
# 3          3        126          2        100         0    NaN   NaN
# 4          3        126          2        100         0    NaN   NaN
#
#    order_count
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
book_df.tail()
# Out:
#         time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 917548    32767                568    0.998275    0.998754    0.997796
# 917549    32767                569    0.998275    0.998754    0.997892
# 917550    32767                571    0.998275    0.998754    0.997892
# 917551    32767                572    0.998275    0.998754    0.997892
# 917552    32767                582    0.998275    0.998754    0.998179
#
#         ask_price2  bid_size1  ask_size1  bid_size2  ask_size2  stock_id  \
# 917548    0.998946         90         90         48         28         0
# 917549    0.998946         91         90        200         28         0
# 917550    0.998946         91         90        100         28         0
# 917551    0.998946         92         90        100         28         0
# 917552    0.998946         92         90         26         28         0
#
#         price  size  order_count
# 917548    NaN   NaN          NaN
# 917549    NaN   NaN          NaN
# 917550    NaN   NaN          NaN
# 917551    NaN   NaN          NaN
# 917552    NaN   NaN          NaN

# %%
def fix_jsonerr(df):
    """
    fix json column error for lightgbm
    """
    df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in df.columns]
    return df

def log_return(list_stock_prices):
    return np.log(list_stock_prices).diff() 

def realized_volatility(series_log_return):
    series_log_return = log_return(series_log_return)
    return np.sqrt(np.sum(series_log_return ** 2))

def fe_row(book):
    """
    Feature engineering (just volatility for now) for each row
    """
    
    # volatility
    for i in [1, 2, ]:  
        # wap
        book[f'book_wap{i}'] = (book[f'bid_price{i}'] * book[f'ask_size{i}'] +
                        book[f'ask_price{i}'] * book[f'bid_size{i}']) / (
                               book[f'bid_size{i}']+ book[f'ask_size{i}'])
        
    # mean wap
    book['book_wap_mean'] = (book['book_wap1'] + book['book_wap2']) / 2
    
    # wap diff
    book['book_wap_diff'] = book['book_wap1'] - book['book_wap2']
    
    # other orderbook features
    book['book_price_spread'] = (book['ask_price1'] - book['bid_price1']) / (book['ask_price1'] + book['bid_price1'])
    book['book_bid_spread'] = book['bid_price1'] - book['bid_price2']
    book['book_ask_spread'] = book['ask_price1'] - book['ask_price2']
    book['book_total_volume'] = book['ask_size1'] + book['ask_size2'] + book['bid_size1'] + book['bid_size2']
    book['book_volume_imbalance'] = (book['ask_size1'] + book['ask_size2']) - (book['bid_size1'] + book['bid_size2'])
    
    return book    

def fe_agg(book_df):
    """
    feature engineering (aggregation by stock_id x time_id)   
    """ 
            
    # features
    book_feats = book_df.columns[book_df.columns.str.startswith('book_')].values.tolist()
    trade_feats = ['price', 'size', 'order_count', 'seconds_in_bucket']
        
    # agg trade features
    trade_df = book_df.groupby(['time_id', 'stock_id'])[trade_feats].agg([
        'sum', 'mean', 'std', 'max', 'min'
    ]).reset_index()
    
    # agg volatility features
    fe_df = book_df.groupby(['time_id', 'stock_id'])[book_feats].agg([
        realized_volatility
    ]).reset_index()
    fe_df.columns = [" ".join(col).strip() for col in fe_df.columns.values]
    
    # merge
    fe_df = fe_df.merge(
        trade_df
        , how='left'
        , on=['time_id', 'stock_id']
    )
    
    return fe_df
    
def fe_all(book_df):
    """
    perform feature engineerings
    """
      
    # row-wise feature engineering
    book_df = fe_row(book_df)
    
    # feature engineering agg by stock_id x time_id 
    fe_df = fe_agg(book_df)
    
    return fe_df
    
def book_fe_by_stock(stock_id=0):
    """
    load orderbook and trade data for the given stock_id and merge
    
    """
    # load data
    book_df = load_book(stock_id, 'train')
    trade_df = load_trade(stock_id, 'train')
    book_feats = book_df.columns.values.tolist()
    
    # merge
    book_df = book_df.merge(
        trade_df
        , how='outer'
        , on=['time_id', 'seconds_in_bucket', 'stock_id']
    )
    
    # sort by time
    book_df = book_df.sort_values(by=['time_id', 'seconds_in_bucket'])
    
    # fillna for book_df
    book_df[book_feats] = book_df[book_feats].fillna(method='ffill')
    
    # feature engineering
    fe_df = fe_all(book_df)
    return fe_df

def book_fe_by_stock_test(stock_id=0):
    """
    same function but for the test
    
    """
    # load data
    book_df = load_book(stock_id, 'test')
    trade_df = load_trade(stock_id, 'test')
    book_feats = book_df.columns.values.tolist()
    
    # merge
    book_df = book_df.merge(
        trade_df
        , how='outer'
        , on=['time_id', 'seconds_in_bucket', 'stock_id']
    )
    
    # sort by time
    book_df = book_df.sort_values(by=['time_id', 'seconds_in_bucket'])
    
    # fillna for book_df
    book_df[book_feats] = book_df[book_feats].fillna(method='ffill')
    
    # feature engineering
    fe_df = fe_all(book_df)
    return fe_df
    
def book_fe_all(stock_ids, data_type='train'): 
    """
    Feature engineering with multithread processing
    """
    # feature engineering agg by stock_id x time_id
    with Pool(cpu_count()) as p:
        if data_type == 'train':
            feature_dfs = list(tqdm(p.imap(book_fe_by_stock, stock_ids), total=len(stock_ids)))
        elif data_type == 'test':
            feature_dfs = list(tqdm(p.imap(book_fe_by_stock_test, stock_ids), total=len(stock_ids)))      
        
    fe_df = pd.concat(feature_dfs)
    
    # feature engineering agg by stock_id
    vol_feats = [f for f in fe_df.columns if ('realized' in f) & ('wap' in f)]
    if data_type == 'train':
        # agg
        stock_df = fe_df.groupby('stock_id')[vol_feats].agg(['mean', 'std', 'max', 'min', ]).reset_index()
        
        # fix column names
        stock_df.columns = ['stock_id'] + [f'{f}_stock' for f in stock_df.columns.values.tolist()[1:]]        
        stock_df = fix_jsonerr(stock_df)
    
    # feature engineering agg by time_id
    time_df = fe_df.groupby('time_id')[vol_feats].agg(['mean', 'std', 'max', 'min', ]).reset_index()
    time_df.columns = ['time_id'] + [f'{f}_time' for f in time_df.columns.values.tolist()[1:]]
    
    # merge
    fe_df = fe_df.merge(
        time_df
        , how='left'
        , on='time_id'
    )
    
    # make sure to fix json error for lighgbm
    fe_df = fix_jsonerr(fe_df)
    
    # out
    if data_type == 'train':
        return fe_df, stock_df
    elif data_type == 'test':
        return fe_df

# %%
# %%time

if MODE == 'TRAIN':
    # all book data feature engineering
    stock_ids = [int(i.split('=')[-1]) for i in train_book_stocks]
    book_df, stock_df = book_fe_all(stock_ids, data_type='train')

    assert book_df['stock_id'].nunique() > 2
    assert book_df['time_id'].nunique() > 2
    
    # save stock_df for the test
    stock_df.to_pickle('train_stock_df.pkl')
    logger.info('train stock df saved!')
    
    # merge
    book_df = book_df.merge(
        stock_df
        , how='left'
        , on='stock_id'
    ).merge(
        train
        , how='left'
        , on=['stock_id', 'time_id']
    ).replace([np.inf, -np.inf], np.nan).fillna(method='ffill')

    # make row_id
    book_df['row_id'] = book_df['stock_id'].astype(str) + '-' + book_df['time_id'].astype(str)

    print(book_df.shape)
    book_df.head()
# Out:
#   0%|          | 0/112 [00:00<?, ?it/s]
# train stock df saved!
# (428932, 65)
# CPU times: user 4.21 s, sys: 1.08 s, total: 5.3 s
# Wall time: 17min 36s

# %%
# test
test_book_stocks = os.listdir(os.path.join(CFG.INPUT_DIR, 'book_test.parquet'))

logger.info('{:,} test book stocks: {}'.format(len(test_book_stocks), test_book_stocks))

# all book data feature engineering
test_stock_ids = [int(i.split('=')[-1]) for i in test_book_stocks]
test_book_df = book_fe_all(test_stock_ids, data_type='test')

# load stock_df, if inference
if MODE == 'INFERENCE':
    stock_df = pd.read_pickle(f'{MODEL_DIR}/train_stock_df.pkl')
    
# merge
test_book_df = test.merge(
    stock_df
    , how='left'
    , on='stock_id'
).merge(
    test_book_df
    , how='left'
    , on=['stock_id', 'time_id']
).replace([np.inf, -np.inf], np.nan).fillna(method='ffill')

# make row_id
test_book_df['row_id'] = test_book_df['stock_id'].astype(str) + '-' + test_book_df['time_id'].astype(str)

print(test_book_df.shape)
test_book_df.head()
# Out:
# 1 test book stocks: ['stock_id=0']
#   0%|          | 0/1 [00:00<?, ?it/s]
# (3, 64)
#    stock_id  time_id row_id  __book_wap1_realized_volatility____mean___stock  \
# 0         0        4    0-4                                         0.004459
# 1         0       32   0-32                                         0.004459
# 2         0       34   0-34                                         0.004459
#
#    __book_wap1_realized_volatility____std___stock  \
# 0                                        0.003698
# 1                                        0.003698
# 2                                        0.003698
#
#    __book_wap1_realized_volatility____max___stock  \
# 0                                        0.052704
# 1                                        0.052704
# 2                                        0.052704
#
#    __book_wap1_realized_volatility____min___stock  \
# 0                                        0.000747
# 1                                        0.000747
# 2                                        0.000747
#
#    __book_wap2_realized_volatility____mean___stock  \
# 0                                         0.006856
# 1                                         0.006856
# 2                                         0.006856
#
#    __book_wap2_realized_volatility____std___stock  \
# 0                                        0.005494
# 1                                        0.005494
# 2                                        0.005494
#
#    __book_wap2_realized_volatility____max___stock  ...  \
# 0                                        0.086671  ...
# 1                                        0.086671  ...
# 2                                        0.086671  ...
#
#    __book_wap2_realized_volatility____max___time  \
# 0                                       0.000252
# 1                                       0.000252
# 2                                       0.000252
#
#    __book_wap2_realized_volatility____min___time  \
# 0                                       0.000252
# 1                                       0.000252
# 2                                       0.000252
#
#    __book_wap_mean_realized_volatility____mean___time  \
# 0                                           0.000273
# 1                                           0.000273
# 2                                           0.000273
#
#    __book_wap_mean_realized_volatility____std___time  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    __book_wap_mean_realized_volatility____max___time  \
# 0                                           0.000273
# 1                                           0.000273
# 2                                           0.000273
#
#    __book_wap_mean_realized_volatility____min___time  \
# 0                                           0.000273
# 1                                           0.000273
# 2                                           0.000273
#
#    __book_wap_diff_realized_volatility____mean___time  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    __book_wap_diff_realized_volatility____std___time  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    __book_wap_diff_realized_volatility____max___time  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    __book_wap_diff_realized_volatility____min___time
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
# [3 rows x 64 columns]

# %% [markdown]
# # Modeling
#
# Currently,
#
# - MODEL: LightGBM (with inverse weighting of the square of the target)
# - OBJECTIVE FUNCTION: RMSE
# - METRIC: RMSPE (used for early stopping)
# - Validation Strategy: KFold (hmm...)

# %%
target = 'target'
drops = [target, 'row_id', 'time_id']
features = [f for f in test_book_df.columns.values.tolist() if f not in drops]
cats = ['stock_id', ]

logger.info('{:,} features ({:,} categorical): {}'.format(len(features), len(cats), features))
# Out:
# 62 features (1 categorical): ['stock_id', '__book_wap1_realized_volatility____mean___stock', '__book_wap1_realized_volatility____std___stock', '__book_wap1_realized_volatility____max___stock', '__book_wap1_realized_volatility____min___stock', '__book_wap2_realized_volatility____mean___stock', '__book_wap2_realized_volatility____std___stock', '__book_wap2_realized_volatility____max___stock', '__book_wap2_realized_volatility____min___stock', '__book_wap_mean_realized_volatility____mean___stock', '__book_wap_mean_realized_volatility____std___stock', '__book_wap_mean_realized_volatility____max___stock', '__book_wap_mean_realized_volatility____min___stock', '__book_wap_diff_realized_volatility____mean___stock', '__book_wap_diff_realized_volatility____std___stock', '__book_wap_diff_realized_volatility____max___stock', '__book_wap_diff_realized_volatility____min___stock', 'book_wap1_realized_volatility', 'book_wap2_realized_volatility', 'book_wap_mean_realized_volatility', 'book_wap_diff_realized_volatility', 'book_price_spread_realized_volatility', 'book_bid_spread_realized_volatility', 'book_ask_spread_realized_volatility', 'book_total_volume_realized_volatility', 'book_volume_imbalance_realized_volatility', '__price____sum__', '__price____mean__', '__price____std__', '__price____max__', '__price____min__', '__size____sum__', '__size____mean__', '__size____std__', '__size____max__', '__size____min__', '__order_count____sum__', '__order_count____mean__', '__order_count____std__', '__order_count____max__', '__order_count____min__', '__seconds_in_bucket____sum__', '__seconds_in_bucket____mean__', '__seconds_in_bucket____std__', '__seconds_in_bucket____max__', '__seconds_in_bucket____min__', '__book_wap1_realized_volatility____mean___time', '__book_wap1_realized_volatility____std___time', '__book_wap1_realized_volatility____max___time', '__book_wap1_realized_volatility____min___time', '__book_wap2_realized_volatility____mean___time', '__book_wap2_realized_volatility____std___time', '__book_wap2_realized_volatility____max___time', '__book_wap2_realized_volatility____min___time', '__book_wap_mean_realized_volatility____mean___time', '__book_wap_mean_realized_volatility____std___time', '__book_wap_mean_realized_volatility____max___time', '__book_wap_mean_realized_volatility____min___time', '__book_wap_diff_realized_volatility____mean___time', '__book_wap_diff_realized_volatility____std___time', '__book_wap_diff_realized_volatility____max___time', '__book_wap_diff_realized_volatility____min___time']

# %%
# evaluation metric
def RMSPEMetric(XGBoost=False):

    def RMSPE(yhat, dtrain, XGBoost=XGBoost):

        y = dtrain.get_label()
        elements = ((y - yhat) / y) ** 2
        if XGBoost:
            return 'RMSPE', float(np.sqrt(np.sum(elements) / len(y)))
        else:
            return 'RMSPE', float(np.sqrt(np.sum(elements) / len(y))), False

    return RMSPE

# %%
# LightGBM parameters
params = {
    'n_estimators': 10000,
    'objective': 'rmse',
    'boosting_type': 'gbdt',
    'max_depth': -1,
    'learning_rate': 0.01,
    'subsample': 0.72,
    'subsample_freq': 4,
    'feature_fraction': 0.8,
    'lambda_l1': 1,
    'lambda_l2': 1,
    'seed': 46,
    'early_stopping_rounds': 100,
    'verbose': -1
}

# %%
def fit_model(params, X_train, y_train, X_test, features=features, cats=[], era='stock_id', fold_type='kfold', n_fold=5, seed=42):
    """
    fit model with cross validation
    """
    
    models = []
    oof_df = X_train[['time_id', 'stock_id', target]].copy()
    oof_df['pred'] = np.nan
    y_preds = np.zeros((len(X_test),))
    
    if fold_type == 'stratifiedshuffle':
        cv = model_selection.StratifiedShuffleSplit(n_splits=n_fold, random_state=seed)
        kf = cv.split(X_train, X_train[era])
    elif fold_type == 'kfold':
        cv = model_selection.KFold(n_splits=n_fold, shuffle=True, random_state=seed)
        kf = cv.split(X_train, y_train)      
    
    fi_df = pd.DataFrame()
    fi_df['features'] = features
    fi_df['importance'] = 0
        
    for fold_id, (train_index, valid_index) in tqdm(enumerate(kf)):
        # split
        X_tr = X_train.loc[train_index, features]
        X_val = X_train.loc[valid_index, features]
        y_tr = y_train.loc[train_index]
        y_val = y_train.loc[valid_index]
        
        # model (note inverse weighting)
        train_set = lgb.Dataset(X_tr, y_tr, categorical_feature=cats, weight=1/np.power(y_tr, 2))
        val_set = lgb.Dataset(X_val, y_val, categorical_feature=cats, weight=1/np.power(y_val, 2))
        model = lgb.train(
            params
            , train_set
            , valid_sets=[train_set, val_set]
            , feval=RMSPEMetric()
            , verbose_eval=250
        )
        
        # feature importance
        fi_df[f'importance_fold{fold_id}'] = model.feature_importance(importance_type="gain")
        fi_df['importance'] += fi_df[f'importance_fold{fold_id}'].values
        
        # save model
        joblib.dump(model, f'model_fold{fold_id}.pkl')
        logger.debug('model saved!')

        # predict
        oof_df['pred'].iloc[valid_index] = model.predict(X_val)
        y_pred = model.predict(X_test[features])
        y_preds += y_pred / n_fold
        models.append(model)
        
    return oof_df, y_preds, models, fi_df

if MODE == 'TRAIN':
    oof_df, y_preds, models, fi_df = fit_model(params, 
                                          book_df, 
                                          book_df[target], 
                                          test_book_df, 
                                          features=features, 
                                          cats=cats,
                                          era=None,
                                          fold_type='kfold', 
                                          n_fold=CFG.N_SPLITS, 
                                          seed=CFG.SEED
                                              )
# Out:
# 0it [00:00, ?it/s]
# Training until validation scores don't improve for 100 rounds
# [250]	training's rmse: 0.000507989	training's RMSPE: 0.23493	valid_1's rmse: 0.000523873	valid_1's RMSPE: 0.244064
# [500]	training's rmse: 0.000479271	training's RMSPE: 0.221649	valid_1's rmse: 0.000494726	valid_1's RMSPE: 0.230485
# [750]	training's rmse: 0.000468664	training's RMSPE: 0.216743	valid_1's rmse: 0.000485671	valid_1's RMSPE: 0.226266
# [1000]	training's rmse: 0.000460626	training's RMSPE: 0.213026	valid_1's rmse: 0.000479711	valid_1's RMSPE: 0.22349
# [1250]	training's rmse: 0.000453936	training's RMSPE: 0.209932	valid_1's rmse: 0.000474619	valid_1's RMSPE: 0.221117
# [1500]	training's rmse: 0.000448703	training's RMSPE: 0.207512	valid_1's rmse: 0.000470754	valid_1's RMSPE: 0.219317
# [1750]	training's rmse: 0.000443979	training's RMSPE: 0.205327	valid_1's rmse: 0.000467533	valid_1's RMSPE: 0.217816
# [2000]	training's rmse: 0.00044001	training's RMSPE: 0.203492	valid_1's rmse: 0.000465854	valid_1's RMSPE: 0.217034
# [2250]	training's rmse: 0.000436158	training's RMSPE: 0.20171	valid_1's rmse: 0.000463665	valid_1's RMSPE: 0.216014
# [2500]	training's rmse: 0.000432865	training's RMSPE: 0.200187	valid_1's rmse: 0.000461961	valid_1's RMSPE: 0.21522
# [2750]	training's rmse: 0.000429965	training's RMSPE: 0.198846	valid_1's rmse: 0.00046046	valid_1's RMSPE: 0.214521
# [3000]	training's rmse: 0.000427278	training's RMSPE: 0.197603	valid_1's rmse: 0.000459314	valid_1's RMSPE: 0.213987
# [3250]	training's rmse: 0.000424687	training's RMSPE: 0.196405	valid_1's rmse: 0.000458323	valid_1's RMSPE: 0.213525
# [3500]	training's rmse: 0.000422239	training's RMSPE: 0.195273	valid_1's rmse: 0.00045744	valid_1's RMSPE: 0.213114
# [3750]	training's rmse: 0.000419739	training's RMSPE: 0.194117	valid_1's rmse: 0.000456017	valid_1's RMSPE: 0.212451
# [4000]	training's rmse: 0.000417425	training's RMSPE: 0.193047	valid_1's rmse: 0.000455193	valid_1's RMSPE: 0.212067
# [4250]	training's rmse: 0.000415068	training's RMSPE: 0.191957	valid_1's rmse: 0.00045404	valid_1's RMSPE: 0.21153
# [4500]	training's rmse: 0.000412955	training's RMSPE: 0.190979	valid_1's rmse: 0.000452936	valid_1's RMSPE: 0.211016
# [4750]	training's rmse: 0.000410966	training's RMSPE: 0.190059	valid_1's rmse: 0.000452219	valid_1's RMSPE: 0.210682
# [5000]	training's rmse: 0.000409117	training's RMSPE: 0.189204	valid_1's rmse: 0.000451535	valid_1's RMSPE: 0.210363
# [5250]	training's rmse: 0.000407319	training's RMSPE: 0.188373	valid_1's rmse: 0.00045066	valid_1's RMSPE: 0.209955
# [5500]	training's rmse: 0.00040557	training's RMSPE: 0.187564	valid_1's rmse: 0.000450025	valid_1's RMSPE: 0.209659
# [5750]	training's rmse: 0.000403836	training's RMSPE: 0.186762	valid_1's rmse: 0.000449467	valid_1's RMSPE: 0.2094
# [6000]	training's rmse: 0.000402097	training's RMSPE: 0.185958	valid_1's rmse: 0.000448791	valid_1's RMSPE: 0.209084
# [6250]	training's rmse: 0.000400531	training's RMSPE: 0.185234	valid_1's rmse: 0.000448185	valid_1's RMSPE: 0.208802
# [6500]	training's rmse: 0.000398927	training's RMSPE: 0.184492	valid_1's rmse: 0.000447482	valid_1's RMSPE: 0.208475
# [6750]	training's rmse: 0.000397507	training's RMSPE: 0.183835	valid_1's rmse: 0.000447131	valid_1's RMSPE: 0.208311
# [7000]	training's rmse: 0.000395964	training's RMSPE: 0.183122	valid_1's rmse: 0.000446417	valid_1's RMSPE: 0.207979
# [7250]	training's rmse: 0.000394445	training's RMSPE: 0.182419	valid_1's rmse: 0.000445906	valid_1's RMSPE: 0.20774
# [7500]	training's rmse: 0.000393064	training's RMSPE: 0.18178	valid_1's rmse: 0.000445512	valid_1's RMSPE: 0.207557
# Early stopping, best iteration is:
# [7608]	training's rmse: 0.000392472	training's RMSPE: 0.181507	valid_1's rmse: 0.000445408	valid_1's RMSPE: 0.207509
# Training until validation scores don't improve for 100 rounds
# [250]	training's rmse: 0.000507547	training's RMSPE: 0.235007	valid_1's rmse: 0.000514596	valid_1's RMSPE: 0.237173
# [500]	training's rmse: 0.000479115	training's RMSPE: 0.221843	valid_1's rmse: 0.000490999	valid_1's RMSPE: 0.226298
# [750]	training's rmse: 0.000468338	training's RMSPE: 0.216852	valid_1's rmse: 0.000482455	valid_1's RMSPE: 0.22236
# [1000]	training's rmse: 0.00046039	training's RMSPE: 0.213172	valid_1's rmse: 0.000476526	valid_1's RMSPE: 0.219627
# [1250]	training's rmse: 0.000453907	training's RMSPE: 0.21017	valid_1's rmse: 0.000472283	valid_1's RMSPE: 0.217672
# [1500]	training's rmse: 0.000448643	training's RMSPE: 0.207733	valid_1's rmse: 0.000468529	valid_1's RMSPE: 0.215942
# [1750]	training's rmse: 0.000444184	training's RMSPE: 0.205669	valid_1's rmse: 0.000466214	valid_1's RMSPE: 0.214874
# [2000]	training's rmse: 0.000439914	training's RMSPE: 0.203691	valid_1's rmse: 0.000463548	valid_1's RMSPE: 0.213646
# [2250]	training's rmse: 0.000436265	training's RMSPE: 0.202002	valid_1's rmse: 0.00046175	valid_1's RMSPE: 0.212817
# [2500]	training's rmse: 0.000432789	training's RMSPE: 0.200392	valid_1's rmse: 0.000459894	valid_1's RMSPE: 0.211962
# [2750]	training's rmse: 0.000429744	training's RMSPE: 0.198982	valid_1's rmse: 0.000458576	valid_1's RMSPE: 0.211354
# [3000]	training's rmse: 0.000427057	training's RMSPE: 0.197738	valid_1's rmse: 0.000457561	valid_1's RMSPE: 0.210886
# [3250]	training's rmse: 0.000424501	training's RMSPE: 0.196555	valid_1's rmse: 0.000456489	valid_1's RMSPE: 0.210392
# [3500]	training's rmse: 0.00042195	training's RMSPE: 0.195374	valid_1's rmse: 0.000455336	valid_1's RMSPE: 0.209861
# [3750]	training's rmse: 0.000419796	training's RMSPE: 0.194376	valid_1's rmse: 0.000454532	valid_1's RMSPE: 0.20949
# [4000]	training's rmse: 0.000417678	training's RMSPE: 0.193396	valid_1's rmse: 0.000453767	valid_1's RMSPE: 0.209138
# [4250]	training's rmse: 0.000415471	training's RMSPE: 0.192374	valid_1's rmse: 0.000453199	valid_1's RMSPE: 0.208876
# [4500]	training's rmse: 0.000413385	training's RMSPE: 0.191408	valid_1's rmse: 0.000452687	valid_1's RMSPE: 0.20864
# [4750]	training's rmse: 0.00041127	training's RMSPE: 0.190429	valid_1's rmse: 0.000451606	valid_1's RMSPE: 0.208142
# [5000]	training's rmse: 0.000409376	training's RMSPE: 0.189551	valid_1's rmse: 0.000450705	valid_1's RMSPE: 0.207726
# [5250]	training's rmse: 0.000407596	training's RMSPE: 0.188727	valid_1's rmse: 0.000450139	valid_1's RMSPE: 0.207466
# [5500]	training's rmse: 0.000405686	training's RMSPE: 0.187843	valid_1's rmse: 0.000449219	valid_1's RMSPE: 0.207042
# [5750]	training's rmse: 0.00040394	training's RMSPE: 0.187035	valid_1's rmse: 0.000448585	valid_1's RMSPE: 0.206749
# [6000]	training's rmse: 0.000402285	training's RMSPE: 0.186268	valid_1's rmse: 0.000448005	valid_1's RMSPE: 0.206482
# [6250]	training's rmse: 0.000400684	training's RMSPE: 0.185527	valid_1's rmse: 0.000447373	valid_1's RMSPE: 0.206191
# [6500]	training's rmse: 0.00039904	training's RMSPE: 0.184766	valid_1's rmse: 0.000446851	valid_1's RMSPE: 0.20595
# [6750]	training's rmse: 0.000397424	training's RMSPE: 0.184018	valid_1's rmse: 0.000446383	valid_1's RMSPE: 0.205735
# [7000]	training's rmse: 0.000395904	training's RMSPE: 0.183314	valid_1's rmse: 0.00044609	valid_1's RMSPE: 0.2056
# [7250]	training's rmse: 0.000394339	training's RMSPE: 0.182589	valid_1's rmse: 0.000445475	valid_1's RMSPE: 0.205316
# [7500]	training's rmse: 0.000392967	training's RMSPE: 0.181954	valid_1's rmse: 0.000445163	valid_1's RMSPE: 0.205172
# [7750]	training's rmse: 0.000391538	training's RMSPE: 0.181292	valid_1's rmse: 0.000444747	valid_1's RMSPE: 0.20498
# [8000]	training's rmse: 0.000390101	training's RMSPE: 0.180627	valid_1's rmse: 0.000444307	valid_1's RMSPE: 0.204778
# [8250]	training's rmse: 0.000388649	training's RMSPE: 0.179954	valid_1's rmse: 0.000443795	valid_1's RMSPE: 0.204542
# [8500]	training's rmse: 0.000387361	training's RMSPE: 0.179358	valid_1's rmse: 0.000443715	valid_1's RMSPE: 0.204505
# [8750]	training's rmse: 0.000385978	training's RMSPE: 0.178718	valid_1's rmse: 0.000443312	valid_1's RMSPE: 0.204319
# [9000]	training's rmse: 0.000384784	training's RMSPE: 0.178165	valid_1's rmse: 0.000443206	valid_1's RMSPE: 0.20427
# [9250]	training's rmse: 0.000383522	training's RMSPE: 0.177581	valid_1's rmse: 0.000442938	valid_1's RMSPE: 0.204147
# [9500]	training's rmse: 0.000382284	training's RMSPE: 0.177007	valid_1's rmse: 0.000442804	valid_1's RMSPE: 0.204085
# Early stopping, best iteration is:
# [9454]	training's rmse: 0.000382501	training's RMSPE: 0.177108	valid_1's rmse: 0.000442708	valid_1's RMSPE: 0.204041
# Training until validation scores don't improve for 100 rounds
# [250]	training's rmse: 0.00050799	training's RMSPE: 0.235137	valid_1's rmse: 0.000508608	valid_1's RMSPE: 0.235095
# [500]	training's rmse: 0.0004792	training's RMSPE: 0.221811	valid_1's rmse: 0.000482732	valid_1's RMSPE: 0.223134
# [750]	training's rmse: 0.000468296	training's RMSPE: 0.216764	valid_1's rmse: 0.000473936	valid_1's RMSPE: 0.219069
# [1000]	training's rmse: 0.000459987	training's RMSPE: 0.212917	valid_1's rmse: 0.00046722	valid_1's RMSPE: 0.215964
# [1250]	training's rmse: 0.000453841	training's RMSPE: 0.210073	valid_1's rmse: 0.000462835	valid_1's RMSPE: 0.213938
# [1500]	training's rmse: 0.000448425	training's RMSPE: 0.207566	valid_1's rmse: 0.000459075	valid_1's RMSPE: 0.212199
# [1750]	training's rmse: 0.000443993	training's RMSPE: 0.205514	valid_1's rmse: 0.000456218	valid_1's RMSPE: 0.210879
# [2000]	training's rmse: 0.000440102	training's RMSPE: 0.203713	valid_1's rmse: 0.000453746	valid_1's RMSPE: 0.209736
# [2250]	training's rmse: 0.000436491	training's RMSPE: 0.202042	valid_1's rmse: 0.000451376	valid_1's RMSPE: 0.208641
# [2500]	training's rmse: 0.000433021	training's RMSPE: 0.200435	valid_1's rmse: 0.000449087	valid_1's RMSPE: 0.207583
# [2750]	training's rmse: 0.00043012	training's RMSPE: 0.199093	valid_1's rmse: 0.000447339	valid_1's RMSPE: 0.206775
# [3000]	training's rmse: 0.000427159	training's RMSPE: 0.197722	valid_1's rmse: 0.000445609	valid_1's RMSPE: 0.205975
# [3250]	training's rmse: 0.000424518	training's RMSPE: 0.1965	valid_1's rmse: 0.000444138	valid_1's RMSPE: 0.205295
# [3500]	training's rmse: 0.00042198	training's RMSPE: 0.195325	valid_1's rmse: 0.000442705	valid_1's RMSPE: 0.204633
# [3750]	training's rmse: 0.000419755	training's RMSPE: 0.194295	valid_1's rmse: 0.000441614	valid_1's RMSPE: 0.204128
# [4000]	training's rmse: 0.000417555	training's RMSPE: 0.193277	valid_1's rmse: 0.000440493	valid_1's RMSPE: 0.20361
# [4250]	training's rmse: 0.000415405	training's RMSPE: 0.192282	valid_1's rmse: 0.000439341	valid_1's RMSPE: 0.203078
# [4500]	training's rmse: 0.000413348	training's RMSPE: 0.191329	valid_1's rmse: 0.00043834	valid_1's RMSPE: 0.202615
# [4750]	training's rmse: 0.000411274	training's RMSPE: 0.190369	valid_1's rmse: 0.000437246	valid_1's RMSPE: 0.202109
# [5000]	training's rmse: 0.000409258	training's RMSPE: 0.189436	valid_1's rmse: 0.000436262	valid_1's RMSPE: 0.201654
# [5250]	training's rmse: 0.000407298	training's RMSPE: 0.188529	valid_1's rmse: 0.00043531	valid_1's RMSPE: 0.201214
# [5500]	training's rmse: 0.00040544	training's RMSPE: 0.187669	valid_1's rmse: 0.000434447	valid_1's RMSPE: 0.200815
# [5750]	training's rmse: 0.000403758	training's RMSPE: 0.18689	valid_1's rmse: 0.000433703	valid_1's RMSPE: 0.200471
# [6000]	training's rmse: 0.00040206	training's RMSPE: 0.186104	valid_1's rmse: 0.000432926	valid_1's RMSPE: 0.200112
# [6250]	training's rmse: 0.000400527	training's RMSPE: 0.185395	valid_1's rmse: 0.000432346	valid_1's RMSPE: 0.199844
# [6500]	training's rmse: 0.000398927	training's RMSPE: 0.184654	valid_1's rmse: 0.00043167	valid_1's RMSPE: 0.199532
# [6750]	training's rmse: 0.000397431	training's RMSPE: 0.183962	valid_1's rmse: 0.000431065	valid_1's RMSPE: 0.199252
# [7000]	training's rmse: 0.000395852	training's RMSPE: 0.183231	valid_1's rmse: 0.000430371	valid_1's RMSPE: 0.198932
# [7250]	training's rmse: 0.000394439	training's RMSPE: 0.182577	valid_1's rmse: 0.000429863	valid_1's RMSPE: 0.198697
# [7500]	training's rmse: 0.000393057	training's RMSPE: 0.181937	valid_1's rmse: 0.000429379	valid_1's RMSPE: 0.198473
# [7750]	training's rmse: 0.000391776	training's RMSPE: 0.181344	valid_1's rmse: 0.000428963	valid_1's RMSPE: 0.198281
# [8000]	training's rmse: 0.000390376	training's RMSPE: 0.180696	valid_1's rmse: 0.000428479	valid_1's RMSPE: 0.198057
# [8250]	training's rmse: 0.00038891	training's RMSPE: 0.180017	valid_1's rmse: 0.000427864	valid_1's RMSPE: 0.197773
# [8500]	training's rmse: 0.000387678	training's RMSPE: 0.179447	valid_1's rmse: 0.00042752	valid_1's RMSPE: 0.197613
# [8750]	training's rmse: 0.000386372	training's RMSPE: 0.178843	valid_1's rmse: 0.000427107	valid_1's RMSPE: 0.197423
# [9000]	training's rmse: 0.000385029	training's RMSPE: 0.178221	valid_1's rmse: 0.000426589	valid_1's RMSPE: 0.197183
# [9250]	training's rmse: 0.000383804	training's RMSPE: 0.177654	valid_1's rmse: 0.000426245	valid_1's RMSPE: 0.197024
# [9500]	training's rmse: 0.000382557	training's RMSPE: 0.177077	valid_1's rmse: 0.000425829	valid_1's RMSPE: 0.196832
# [9750]	training's rmse: 0.000381378	training's RMSPE: 0.176531	valid_1's rmse: 0.000425531	valid_1's RMSPE: 0.196694
# [10000]	training's rmse: 0.00038022	training's RMSPE: 0.175995	valid_1's rmse: 0.000425193	valid_1's RMSPE: 0.196538
# Did not meet early stopping. Best iteration is:
# [10000]	training's rmse: 0.00038022	training's RMSPE: 0.175995	valid_1's rmse: 0.000425193	valid_1's RMSPE: 0.196538
# Training until validation scores don't improve for 100 rounds
# [250]	training's rmse: 0.000507748	training's RMSPE: 0.23487	valid_1's rmse: 0.000519227	valid_1's RMSPE: 0.241427
# [500]	training's rmse: 0.00047878	training's RMSPE: 0.22147	valid_1's rmse: 0.000491543	valid_1's RMSPE: 0.228554
# [750]	training's rmse: 0.000468406	training's RMSPE: 0.216672	valid_1's rmse: 0.0004839	valid_1's RMSPE: 0.225001
# [1000]	training's rmse: 0.000460448	training's RMSPE: 0.21299	valid_1's rmse: 0.000479696	valid_1's RMSPE: 0.223046
# [1250]	training's rmse: 0.000454129	training's RMSPE: 0.210067	valid_1's rmse: 0.000476842	valid_1's RMSPE: 0.221719
# [1500]	training's rmse: 0.000449034	training's RMSPE: 0.207711	valid_1's rmse: 0.000474311	valid_1's RMSPE: 0.220542
# Early stopping, best iteration is:
# [1488]	training's rmse: 0.0004493	training's RMSPE: 0.207834	valid_1's rmse: 0.000474275	valid_1's RMSPE: 0.220525
# Training until validation scores don't improve for 100 rounds
# [250]	training's rmse: 0.000507201	training's RMSPE: 0.23472	valid_1's rmse: 0.000541529	valid_1's RMSPE: 0.25081
# [500]	training's rmse: 0.000478619	training's RMSPE: 0.221493	valid_1's rmse: 0.000512132	valid_1's RMSPE: 0.237195
# [750]	training's rmse: 0.000467702	training's RMSPE: 0.216441	valid_1's rmse: 0.000500496	valid_1's RMSPE: 0.231805
# [1000]	training's rmse: 0.000459795	training's RMSPE: 0.212782	valid_1's rmse: 0.000493265	valid_1's RMSPE: 0.228457
# [1250]	training's rmse: 0.000453264	training's RMSPE: 0.209759	valid_1's rmse: 0.000487679	valid_1's RMSPE: 0.225869
# [1500]	training's rmse: 0.000448097	training's RMSPE: 0.207368	valid_1's rmse: 0.000483347	valid_1's RMSPE: 0.223863
# [1750]	training's rmse: 0.000443109	training's RMSPE: 0.20506	valid_1's rmse: 0.000479275	valid_1's RMSPE: 0.221977
# [2000]	training's rmse: 0.000439276	training's RMSPE: 0.203286	valid_1's rmse: 0.000477435	valid_1's RMSPE: 0.221125
# [2250]	training's rmse: 0.000435678	training's RMSPE: 0.201621	valid_1's rmse: 0.000474349	valid_1's RMSPE: 0.219696
# [2500]	training's rmse: 0.000432491	training's RMSPE: 0.200146	valid_1's rmse: 0.000473175	valid_1's RMSPE: 0.219152
# [2750]	training's rmse: 0.000429345	training's RMSPE: 0.19869	valid_1's rmse: 0.00047092	valid_1's RMSPE: 0.218107
# [3000]	training's rmse: 0.000426593	training's RMSPE: 0.197417	valid_1's rmse: 0.000469296	valid_1's RMSPE: 0.217355
# [3250]	training's rmse: 0.0004239	training's RMSPE: 0.19617	valid_1's rmse: 0.000467967	valid_1's RMSPE: 0.21674
# [3500]	training's rmse: 0.00042126	training's RMSPE: 0.194949	valid_1's rmse: 0.000466192	valid_1's RMSPE: 0.215918
# [3750]	training's rmse: 0.000419028	training's RMSPE: 0.193916	valid_1's rmse: 0.000465056	valid_1's RMSPE: 0.215391
# [4000]	training's rmse: 0.000416908	training's RMSPE: 0.192935	valid_1's rmse: 0.000464363	valid_1's RMSPE: 0.21507
# [4250]	training's rmse: 0.000414511	training's RMSPE: 0.191825	valid_1's rmse: 0.000462957	valid_1's RMSPE: 0.214419
# [4500]	training's rmse: 0.000412485	training's RMSPE: 0.190888	valid_1's rmse: 0.000461665	valid_1's RMSPE: 0.213821
# [4750]	training's rmse: 0.000410444	training's RMSPE: 0.189943	valid_1's rmse: 0.000460448	valid_1's RMSPE: 0.213257
# [5000]	training's rmse: 0.000408508	training's RMSPE: 0.189047	valid_1's rmse: 0.000460116	valid_1's RMSPE: 0.213103
# [5250]	training's rmse: 0.000406613	training's RMSPE: 0.18817	valid_1's rmse: 0.000459357	valid_1's RMSPE: 0.212752
# [5500]	training's rmse: 0.000404648	training's RMSPE: 0.187261	valid_1's rmse: 0.000458295	valid_1's RMSPE: 0.21226
# [5750]	training's rmse: 0.000402804	training's RMSPE: 0.186408	valid_1's rmse: 0.000457612	valid_1's RMSPE: 0.211944
# Early stopping, best iteration is:
# [5833]	training's rmse: 0.00040224	training's RMSPE: 0.186146	valid_1's rmse: 0.000457357	valid_1's RMSPE: 0.211826
# Training until validation scores don't improve for 100 rounds
# [250]	training's rmse: 0.000508007	training's RMSPE: 0.235129	valid_1's rmse: 0.000512184	valid_1's RMSPE: 0.236891
# [500]	training's rmse: 0.000479108	training's RMSPE: 0.221753	valid_1's rmse: 0.000484488	valid_1's RMSPE: 0.224081
# [750]	training's rmse: 0.000468681	training's RMSPE: 0.216927	valid_1's rmse: 0.000477443	valid_1's RMSPE: 0.220823
# [1000]	training's rmse: 0.000460404	training's RMSPE: 0.213096	valid_1's rmse: 0.000471571	valid_1's RMSPE: 0.218107
# [1250]	training's rmse: 0.00045395	training's RMSPE: 0.210109	valid_1's rmse: 0.000467075	valid_1's RMSPE: 0.216027
# [1500]	training's rmse: 0.000448588	training's RMSPE: 0.207627	valid_1's rmse: 0.000464024	valid_1's RMSPE: 0.214616
# [1750]	training's rmse: 0.00044403	training's RMSPE: 0.205518	valid_1's rmse: 0.000461373	valid_1's RMSPE: 0.21339
# [2000]	training's rmse: 0.00044003	training's RMSPE: 0.203666	valid_1's rmse: 0.000459064	valid_1's RMSPE: 0.212322
# [2250]	training's rmse: 0.000436114	training's RMSPE: 0.201854	valid_1's rmse: 0.000456649	valid_1's RMSPE: 0.211205
# [2500]	training's rmse: 0.000432804	training's RMSPE: 0.200322	valid_1's rmse: 0.000454991	valid_1's RMSPE: 0.210438
# [2750]	training's rmse: 0.00042965	training's RMSPE: 0.198862	valid_1's rmse: 0.0004535	valid_1's RMSPE: 0.209749
# [3000]	training's rmse: 0.000426969	training's RMSPE: 0.197621	valid_1's rmse: 0.000452137	valid_1's RMSPE: 0.209118
# [3250]	training's rmse: 0.000424195	training's RMSPE: 0.196337	valid_1's rmse: 0.000450856	valid_1's RMSPE: 0.208525
# [3500]	training's rmse: 0.000421794	training's RMSPE: 0.195226	valid_1's rmse: 0.000449732	valid_1's RMSPE: 0.208006
# [3750]	training's rmse: 0.000419511	training's RMSPE: 0.194169	valid_1's rmse: 0.000448874	valid_1's RMSPE: 0.207609
# [4000]	training's rmse: 0.00041726	training's RMSPE: 0.193127	valid_1's rmse: 0.000447952	valid_1's RMSPE: 0.207182
# [4250]	training's rmse: 0.000414878	training's RMSPE: 0.192025	valid_1's rmse: 0.000447012	valid_1's RMSPE: 0.206748
# [4500]	training's rmse: 0.000412881	training's RMSPE: 0.1911	valid_1's rmse: 0.000446217	valid_1's RMSPE: 0.20638
# [4750]	training's rmse: 0.000410899	training's RMSPE: 0.190183	valid_1's rmse: 0.000445343	valid_1's RMSPE: 0.205976
# [5000]	training's rmse: 0.000408887	training's RMSPE: 0.189252	valid_1's rmse: 0.00044441	valid_1's RMSPE: 0.205545
# [5250]	training's rmse: 0.000407008	training's RMSPE: 0.188382	valid_1's rmse: 0.000443702	valid_1's RMSPE: 0.205217
# [5500]	training's rmse: 0.000405264	training's RMSPE: 0.187575	valid_1's rmse: 0.000443302	valid_1's RMSPE: 0.205032
# [5750]	training's rmse: 0.000403478	training's RMSPE: 0.186748	valid_1's rmse: 0.000442494	valid_1's RMSPE: 0.204658
# [6000]	training's rmse: 0.000401898	training's RMSPE: 0.186017	valid_1's rmse: 0.000441842	valid_1's RMSPE: 0.204357
# [6250]	training's rmse: 0.000400382	training's RMSPE: 0.185315	valid_1's rmse: 0.00044148	valid_1's RMSPE: 0.204189
# [6500]	training's rmse: 0.000398803	training's RMSPE: 0.184584	valid_1's rmse: 0.000440928	valid_1's RMSPE: 0.203934
# [6750]	training's rmse: 0.000397256	training's RMSPE: 0.183869	valid_1's rmse: 0.000440475	valid_1's RMSPE: 0.203725
# [7000]	training's rmse: 0.000395644	training's RMSPE: 0.183122	valid_1's rmse: 0.000439681	valid_1's RMSPE: 0.203357
# [7250]	training's rmse: 0.000394167	training's RMSPE: 0.182439	valid_1's rmse: 0.000439109	valid_1's RMSPE: 0.203093
# [7500]	training's rmse: 0.000392855	training's RMSPE: 0.181831	valid_1's rmse: 0.000438841	valid_1's RMSPE: 0.202969
# [7750]	training's rmse: 0.000391305	training's RMSPE: 0.181114	valid_1's rmse: 0.000438261	valid_1's RMSPE: 0.202701
# [8000]	training's rmse: 0.000389923	training's RMSPE: 0.180474	valid_1's rmse: 0.000437772	valid_1's RMSPE: 0.202474
# [8250]	training's rmse: 0.000388614	training's RMSPE: 0.179868	valid_1's rmse: 0.000437255	valid_1's RMSPE: 0.202235
# [8500]	training's rmse: 0.00038734	training's RMSPE: 0.179279	valid_1's rmse: 0.00043701	valid_1's RMSPE: 0.202122
# [8750]	training's rmse: 0.000386088	training's RMSPE: 0.178699	valid_1's rmse: 0.00043673	valid_1's RMSPE: 0.201992
# Early stopping, best iteration is:
# [8744]	training's rmse: 0.000386111	training's RMSPE: 0.17871	valid_1's rmse: 0.000436523	valid_1's RMSPE: 0.201897
# Training until validation scores don't improve for 100 rounds
# [250]	training's rmse: 0.000507738	training's RMSPE: 0.234994	valid_1's rmse: 0.000513665	valid_1's RMSPE: 0.237676
# [500]	training's rmse: 0.000479028	training's RMSPE: 0.221706	valid_1's rmse: 0.000486628	valid_1's RMSPE: 0.225166
# [750]	training's rmse: 0.000468091	training's RMSPE: 0.216644	valid_1's rmse: 0.000478669	valid_1's RMSPE: 0.221483
# [1000]	training's rmse: 0.000460239	training's RMSPE: 0.21301	valid_1's rmse: 0.000473441	valid_1's RMSPE: 0.219064
# [1250]	training's rmse: 0.000453737	training's RMSPE: 0.210001	valid_1's rmse: 0.000469335	valid_1's RMSPE: 0.217165
# [1500]	training's rmse: 0.000448204	training's RMSPE: 0.20744	valid_1's rmse: 0.000465681	valid_1's RMSPE: 0.215474
# [1750]	training's rmse: 0.00044364	training's RMSPE: 0.205328	valid_1's rmse: 0.000462969	valid_1's RMSPE: 0.214219
# [2000]	training's rmse: 0.000439812	training's RMSPE: 0.203556	valid_1's rmse: 0.000461189	valid_1's RMSPE: 0.213395
# [2250]	training's rmse: 0.0004362	training's RMSPE: 0.201884	valid_1's rmse: 0.000459646	valid_1's RMSPE: 0.212682
# [2500]	training's rmse: 0.000433	training's RMSPE: 0.200403	valid_1's rmse: 0.000457745	valid_1's RMSPE: 0.211802
# [2750]	training's rmse: 0.000429928	training's RMSPE: 0.198981	valid_1's rmse: 0.000456031	valid_1's RMSPE: 0.211009
# [3000]	training's rmse: 0.000427222	training's RMSPE: 0.197729	valid_1's rmse: 0.000455008	valid_1's RMSPE: 0.210536
# [3250]	training's rmse: 0.000424576	training's RMSPE: 0.196504	valid_1's rmse: 0.000453942	valid_1's RMSPE: 0.210042
# [3500]	training's rmse: 0.000422069	training's RMSPE: 0.195344	valid_1's rmse: 0.00045278	valid_1's RMSPE: 0.209505
# [3750]	training's rmse: 0.000419694	training's RMSPE: 0.194245	valid_1's rmse: 0.000452081	valid_1's RMSPE: 0.209181
# [4000]	training's rmse: 0.00041756	training's RMSPE: 0.193257	valid_1's rmse: 0.000451174	valid_1's RMSPE: 0.208761
# [4250]	training's rmse: 0.000415229	training's RMSPE: 0.192178	valid_1's rmse: 0.000449975	valid_1's RMSPE: 0.208207
# Early stopping, best iteration is:
# [4313]	training's rmse: 0.000414692	training's RMSPE: 0.19193	valid_1's rmse: 0.000449765	valid_1's RMSPE: 0.208109
# Training until validation scores don't improve for 100 rounds
# [250]	training's rmse: 0.000507057	training's RMSPE: 0.234981	valid_1's rmse: 0.000516702	valid_1's RMSPE: 0.236286
# [500]	training's rmse: 0.000478278	training's RMSPE: 0.221644	valid_1's rmse: 0.00049159	valid_1's RMSPE: 0.224803
# [750]	training's rmse: 0.00046782	training's RMSPE: 0.216798	valid_1's rmse: 0.000482982	valid_1's RMSPE: 0.220866
# [1000]	training's rmse: 0.000460115	training's RMSPE: 0.213227	valid_1's rmse: 0.000476807	valid_1's RMSPE: 0.218042
# [1250]	training's rmse: 0.000453931	training's RMSPE: 0.210361	valid_1's rmse: 0.000472032	valid_1's RMSPE: 0.215859
# [1500]	training's rmse: 0.000448535	training's RMSPE: 0.207861	valid_1's rmse: 0.000467932	valid_1's RMSPE: 0.213984
# [1750]	training's rmse: 0.000444036	training's RMSPE: 0.205776	valid_1's rmse: 0.000464961	valid_1's RMSPE: 0.212625
# [2000]	training's rmse: 0.000440009	training's RMSPE: 0.20391	valid_1's rmse: 0.000462194	valid_1's RMSPE: 0.21136
# [2250]	training's rmse: 0.000436419	training's RMSPE: 0.202246	valid_1's rmse: 0.00045983	valid_1's RMSPE: 0.210279
# [2500]	training's rmse: 0.000433109	training's RMSPE: 0.200712	valid_1's rmse: 0.000457626	valid_1's RMSPE: 0.209271
# [2750]	training's rmse: 0.000429996	training's RMSPE: 0.199269	valid_1's rmse: 0.000455672	valid_1's RMSPE: 0.208377
# [3000]	training's rmse: 0.000427235	training's RMSPE: 0.19799	valid_1's rmse: 0.000453994	valid_1's RMSPE: 0.20761
# [3250]	training's rmse: 0.000424588	training's RMSPE: 0.196763	valid_1's rmse: 0.000452584	valid_1's RMSPE: 0.206965
# [3500]	training's rmse: 0.000422016	training's RMSPE: 0.195571	valid_1's rmse: 0.000450992	valid_1's RMSPE: 0.206237
# [3750]	training's rmse: 0.000419586	training's RMSPE: 0.194445	valid_1's rmse: 0.000449589	valid_1's RMSPE: 0.205596
# [4000]	training's rmse: 0.000417154	training's RMSPE: 0.193318	valid_1's rmse: 0.000448253	valid_1's RMSPE: 0.204984
# [4250]	training's rmse: 0.000414892	training's RMSPE: 0.19227	valid_1's rmse: 0.000447011	valid_1's RMSPE: 0.204417
# [4500]	training's rmse: 0.000412875	training's RMSPE: 0.191335	valid_1's rmse: 0.000446103	valid_1's RMSPE: 0.204001
# [4750]	training's rmse: 0.000410768	training's RMSPE: 0.190359	valid_1's rmse: 0.000444987	valid_1's RMSPE: 0.203491
# [5000]	training's rmse: 0.000408951	training's RMSPE: 0.189517	valid_1's rmse: 0.000444143	valid_1's RMSPE: 0.203105
# [5250]	training's rmse: 0.000406973	training's RMSPE: 0.1886	valid_1's rmse: 0.000443158	valid_1's RMSPE: 0.202655
# [5500]	training's rmse: 0.000405228	training's RMSPE: 0.187792	valid_1's rmse: 0.000442424	valid_1's RMSPE: 0.202319
# [5750]	training's rmse: 0.000403362	training's RMSPE: 0.186927	valid_1's rmse: 0.000441457	valid_1's RMSPE: 0.201877
# [6000]	training's rmse: 0.000401738	training's RMSPE: 0.186174	valid_1's rmse: 0.000440794	valid_1's RMSPE: 0.201574
# [6250]	training's rmse: 0.000400142	training's RMSPE: 0.185434	valid_1's rmse: 0.000440097	valid_1's RMSPE: 0.201255
# [6500]	training's rmse: 0.000398587	training's RMSPE: 0.184714	valid_1's rmse: 0.00043945	valid_1's RMSPE: 0.200959
# [6750]	training's rmse: 0.000397143	training's RMSPE: 0.184045	valid_1's rmse: 0.00043892	valid_1's RMSPE: 0.200717
# [7000]	training's rmse: 0.000395492	training's RMSPE: 0.18328	valid_1's rmse: 0.000438206	valid_1's RMSPE: 0.20039
# [7250]	training's rmse: 0.00039395	training's RMSPE: 0.182565	valid_1's rmse: 0.000437487	valid_1's RMSPE: 0.200061
# [7500]	training's rmse: 0.000392614	training's RMSPE: 0.181946	valid_1's rmse: 0.000437149	valid_1's RMSPE: 0.199907
# [7750]	training's rmse: 0.000391196	training's RMSPE: 0.181289	valid_1's rmse: 0.000436638	valid_1's RMSPE: 0.199673
# [8000]	training's rmse: 0.000389756	training's RMSPE: 0.180621	valid_1's rmse: 0.000436038	valid_1's RMSPE: 0.199399
# [8250]	training's rmse: 0.000388343	training's RMSPE: 0.179966	valid_1's rmse: 0.000435459	valid_1's RMSPE: 0.199134
# [8500]	training's rmse: 0.000387146	training's RMSPE: 0.179412	valid_1's rmse: 0.000435133	valid_1's RMSPE: 0.198985
# [8750]	training's rmse: 0.000385946	training's RMSPE: 0.178856	valid_1's rmse: 0.000434843	valid_1's RMSPE: 0.198852
# [9000]	training's rmse: 0.000384716	training's RMSPE: 0.178286	valid_1's rmse: 0.000434418	valid_1's RMSPE: 0.198658
# [9250]	training's rmse: 0.000383462	training's RMSPE: 0.177704	valid_1's rmse: 0.000433917	valid_1's RMSPE: 0.198429
# [9500]	training's rmse: 0.00038218	training's RMSPE: 0.17711	valid_1's rmse: 0.000433423	valid_1's RMSPE: 0.198203
# [9750]	training's rmse: 0.000381019	training's RMSPE: 0.176572	valid_1's rmse: 0.00043312	valid_1's RMSPE: 0.198064
# [10000]	training's rmse: 0.000379863	training's RMSPE: 0.176037	valid_1's rmse: 0.000432794	valid_1's RMSPE: 0.197915
# Did not meet early stopping. Best iteration is:
# [10000]	training's rmse: 0.000379863	training's RMSPE: 0.176037	valid_1's rmse: 0.000432794	valid_1's RMSPE: 0.197915
# Training until validation scores don't improve for 100 rounds
# [250]	training's rmse: 0.000507811	training's RMSPE: 0.234939	valid_1's rmse: 0.000513436	valid_1's RMSPE: 0.238371
# [500]	training's rmse: 0.000479086	training's RMSPE: 0.22165	valid_1's rmse: 0.000487526	valid_1's RMSPE: 0.226342
# [750]	training's rmse: 0.000468233	training's RMSPE: 0.216628	valid_1's rmse: 0.000479457	valid_1's RMSPE: 0.222596
# [1000]	training's rmse: 0.000460784	training's RMSPE: 0.213182	valid_1's rmse: 0.000474925	valid_1's RMSPE: 0.220492
# [1250]	training's rmse: 0.000454488	training's RMSPE: 0.210269	valid_1's rmse: 0.000471345	valid_1's RMSPE: 0.21883
# [1500]	training's rmse: 0.000449028	training's RMSPE: 0.207743	valid_1's rmse: 0.000468027	valid_1's RMSPE: 0.217289
# [1750]	training's rmse: 0.000444306	training's RMSPE: 0.205559	valid_1's rmse: 0.000465234	valid_1's RMSPE: 0.215993
# [2000]	training's rmse: 0.000440489	training's RMSPE: 0.203792	valid_1's rmse: 0.000463416	valid_1's RMSPE: 0.215149
# [2250]	training's rmse: 0.000436648	training's RMSPE: 0.202016	valid_1's rmse: 0.000461611	valid_1's RMSPE: 0.21431
# [2500]	training's rmse: 0.000433188	training's RMSPE: 0.200415	valid_1's rmse: 0.000459571	valid_1's RMSPE: 0.213363
# [2750]	training's rmse: 0.000430148	training's RMSPE: 0.199009	valid_1's rmse: 0.000458029	valid_1's RMSPE: 0.212647
# [3000]	training's rmse: 0.000427255	training's RMSPE: 0.19767	valid_1's rmse: 0.000456847	valid_1's RMSPE: 0.212099
# [3250]	training's rmse: 0.000424675	training's RMSPE: 0.196476	valid_1's rmse: 0.00045568	valid_1's RMSPE: 0.211557
# [3500]	training's rmse: 0.000422163	training's RMSPE: 0.195314	valid_1's rmse: 0.000454604	valid_1's RMSPE: 0.211058
# [3750]	training's rmse: 0.000419789	training's RMSPE: 0.194216	valid_1's rmse: 0.000453803	valid_1's RMSPE: 0.210686
# [4000]	training's rmse: 0.000417595	training's RMSPE: 0.193201	valid_1's rmse: 0.00045327	valid_1's RMSPE: 0.210438
# [4250]	training's rmse: 0.000415411	training's RMSPE: 0.19219	valid_1's rmse: 0.00045237	valid_1's RMSPE: 0.21002
# [4500]	training's rmse: 0.000413468	training's RMSPE: 0.191291	valid_1's rmse: 0.000451778	valid_1's RMSPE: 0.209745
# [4750]	training's rmse: 0.000411295	training's RMSPE: 0.190286	valid_1's rmse: 0.000450891	valid_1's RMSPE: 0.209333
# [5000]	training's rmse: 0.000409461	training's RMSPE: 0.189438	valid_1's rmse: 0.000450446	valid_1's RMSPE: 0.209127
# [5250]	training's rmse: 0.000407518	training's RMSPE: 0.188538	valid_1's rmse: 0.000449827	valid_1's RMSPE: 0.20884
# [5500]	training's rmse: 0.000405614	training's RMSPE: 0.187657	valid_1's rmse: 0.000449021	valid_1's RMSPE: 0.208465
# [5750]	training's rmse: 0.000403885	training's RMSPE: 0.186858	valid_1's rmse: 0.000448534	valid_1's RMSPE: 0.208239
# [6000]	training's rmse: 0.000402171	training's RMSPE: 0.186065	valid_1's rmse: 0.000448156	valid_1's RMSPE: 0.208064
# [6250]	training's rmse: 0.000400618	training's RMSPE: 0.185346	valid_1's rmse: 0.000447628	valid_1's RMSPE: 0.207819
# [6500]	training's rmse: 0.000398939	training's RMSPE: 0.18457	valid_1's rmse: 0.00044698	valid_1's RMSPE: 0.207518
# [6750]	training's rmse: 0.000397534	training's RMSPE: 0.18392	valid_1's rmse: 0.000446683	valid_1's RMSPE: 0.20738
# [7000]	training's rmse: 0.000396023	training's RMSPE: 0.18322	valid_1's rmse: 0.000446148	valid_1's RMSPE: 0.207132
# [7250]	training's rmse: 0.000394548	training's RMSPE: 0.182538	valid_1's rmse: 0.000445755	valid_1's RMSPE: 0.206949
# [7500]	training's rmse: 0.000393232	training's RMSPE: 0.181929	valid_1's rmse: 0.000445324	valid_1's RMSPE: 0.206749
# [7750]	training's rmse: 0.000391796	training's RMSPE: 0.181265	valid_1's rmse: 0.000444801	valid_1's RMSPE: 0.206506
# [8000]	training's rmse: 0.000390374	training's RMSPE: 0.180607	valid_1's rmse: 0.000444445	valid_1's RMSPE: 0.206341
# [8250]	training's rmse: 0.000388991	training's RMSPE: 0.179967	valid_1's rmse: 0.000443996	valid_1's RMSPE: 0.206132
# Early stopping, best iteration is:
# [8276]	training's rmse: 0.000388824	training's RMSPE: 0.17989	valid_1's rmse: 0.000443933	valid_1's RMSPE: 0.206103
# Training until validation scores don't improve for 100 rounds
# [250]	training's rmse: 0.000508046	training's RMSPE: 0.235054	valid_1's rmse: 0.000512304	valid_1's RMSPE: 0.237789
# [500]	training's rmse: 0.000478866	training's RMSPE: 0.221554	valid_1's rmse: 0.000486327	valid_1's RMSPE: 0.225731
# [750]	training's rmse: 0.000468218	training's RMSPE: 0.216627	valid_1's rmse: 0.000478391	valid_1's RMSPE: 0.222048
# [1000]	training's rmse: 0.000460432	training's RMSPE: 0.213025	valid_1's rmse: 0.000472652	valid_1's RMSPE: 0.219384
# [1250]	training's rmse: 0.000453999	training's RMSPE: 0.210048	valid_1's rmse: 0.000467847	valid_1's RMSPE: 0.217154
# [1500]	training's rmse: 0.000448407	training's RMSPE: 0.207461	valid_1's rmse: 0.0004639	valid_1's RMSPE: 0.215322
# [1750]	training's rmse: 0.000444055	training's RMSPE: 0.205448	valid_1's rmse: 0.000461179	valid_1's RMSPE: 0.214059
# [2000]	training's rmse: 0.000440185	training's RMSPE: 0.203657	valid_1's rmse: 0.000459449	valid_1's RMSPE: 0.213256
# [2250]	training's rmse: 0.0004364	training's RMSPE: 0.201906	valid_1's rmse: 0.000457201	valid_1's RMSPE: 0.212212
# [2500]	training's rmse: 0.00043313	training's RMSPE: 0.200393	valid_1's rmse: 0.00045521	valid_1's RMSPE: 0.211288
# [2750]	training's rmse: 0.00043023	training's RMSPE: 0.199052	valid_1's rmse: 0.000453652	valid_1's RMSPE: 0.210565
# [3000]	training's rmse: 0.000427478	training's RMSPE: 0.197778	valid_1's rmse: 0.000452098	valid_1's RMSPE: 0.209844
# [3250]	training's rmse: 0.00042477	training's RMSPE: 0.196525	valid_1's rmse: 0.000450823	valid_1's RMSPE: 0.209252
# [3500]	training's rmse: 0.000422157	training's RMSPE: 0.195317	valid_1's rmse: 0.000449587	valid_1's RMSPE: 0.208678
# [3750]	training's rmse: 0.000419839	training's RMSPE: 0.194244	valid_1's rmse: 0.000448578	valid_1's RMSPE: 0.20821
# [4000]	training's rmse: 0.000417548	training's RMSPE: 0.193184	valid_1's rmse: 0.000447487	valid_1's RMSPE: 0.207704
# [4250]	training's rmse: 0.000415442	training's RMSPE: 0.19221	valid_1's rmse: 0.000446663	valid_1's RMSPE: 0.207321
# [4500]	training's rmse: 0.00041344	training's RMSPE: 0.191284	valid_1's rmse: 0.000445622	valid_1's RMSPE: 0.206838
# [4750]	training's rmse: 0.000411579	training's RMSPE: 0.190422	valid_1's rmse: 0.000444992	valid_1's RMSPE: 0.206546
# [5000]	training's rmse: 0.000409652	training's RMSPE: 0.189531	valid_1's rmse: 0.000444005	valid_1's RMSPE: 0.206087
# [5250]	training's rmse: 0.000407625	training's RMSPE: 0.188593	valid_1's rmse: 0.000442924	valid_1's RMSPE: 0.205586
# [5500]	training's rmse: 0.000405774	training's RMSPE: 0.187737	valid_1's rmse: 0.000442288	valid_1's RMSPE: 0.20529
# [5750]	training's rmse: 0.000403833	training's RMSPE: 0.186839	valid_1's rmse: 0.000441548	valid_1's RMSPE: 0.204947
# [6000]	training's rmse: 0.000402132	training's RMSPE: 0.186052	valid_1's rmse: 0.00044083	valid_1's RMSPE: 0.204613
# [6250]	training's rmse: 0.000400524	training's RMSPE: 0.185308	valid_1's rmse: 0.000440489	valid_1's RMSPE: 0.204455
# [6500]	training's rmse: 0.000398974	training's RMSPE: 0.184591	valid_1's rmse: 0.000439879	valid_1's RMSPE: 0.204172
# [6750]	training's rmse: 0.000397582	training's RMSPE: 0.183946	valid_1's rmse: 0.000439556	valid_1's RMSPE: 0.204022
# [7000]	training's rmse: 0.000395922	training's RMSPE: 0.183179	valid_1's rmse: 0.000438865	valid_1's RMSPE: 0.203702
# [7250]	training's rmse: 0.000394535	training's RMSPE: 0.182537	valid_1's rmse: 0.00043846	valid_1's RMSPE: 0.203514
# [7500]	training's rmse: 0.000393156	training's RMSPE: 0.181899	valid_1's rmse: 0.000438003	valid_1's RMSPE: 0.203302
# [7750]	training's rmse: 0.00039172	training's RMSPE: 0.181234	valid_1's rmse: 0.000437412	valid_1's RMSPE: 0.203027
# Early stopping, best iteration is:
# [7888]	training's rmse: 0.000390923	training's RMSPE: 0.180866	valid_1's rmse: 0.000437047	valid_1's RMSPE: 0.202858

# %% [markdown]
# # CV (Cross-Validation) Score
# How good is my model?

# %%
from sklearn.metrics import r2_score
def rmspe(y_true, y_pred):
    return  (np.sqrt(np.mean(np.square((y_true - y_pred) / y_true))))

if MODE == 'TRAIN':
    oof_df.dropna(inplace=True)
    y_true = oof_df[target].values
    y_pred = oof_df['pred'].values
    
    oof_df[target].hist(bins=100)
    oof_df['pred'].hist(bins=100)
    
    R2 = round(r2_score(y_true, y_pred), 3)
    RMSPE = round(rmspe(y_true, y_pred), 3)
    logger.info(f'Performance of the naive prediction: R2 score: {R2}, RMSPE: {RMSPE}')

# %% [markdown]
# We might want to take a look at by-stock performance: there may be some stocks whose volatility are difficult to predict.

# %%
# performance by stock_id
if MODE == 'TRAIN':
    score_df = pd.DataFrame()
    score_df['stock_id'] = oof_df['stock_id'].unique()
    score_df['R2'] = np.nan
    score_df['RMSPE'] = np.nan
    for stock_id in oof_df['stock_id'].unique():
        y_true = oof_df.query('stock_id == @stock_id')[target].values
        y_pred = oof_df.query('stock_id == @stock_id')['pred'].values
        
        R2 = round(r2_score(y_true, y_pred), 3)
        RMSPE = round(rmspe(y_true, y_pred), 3)
        logger.info(f'Performance by stock_id={stock_id}: R2 score: {R2}, RMSPE: {RMSPE}')
        
        score_df.loc[score_df['stock_id'] == stock_id, 'R2'] = R2
        score_df.loc[score_df['stock_id'] == stock_id, 'RMSPE'] = RMSPE
    
    # save score dataframe for further analysis
    score_df.to_csv('score_df.csv', index=False)
    logger.info('Scores saved!')

# %% [markdown]
# # Feature Importance
# Let's see top features for the prediction.

# %%
if MODE == 'TRAIN':
    fi_df = fi_df.sort_values(by='importance', ascending=False)
    fi_df.to_csv('feature_importance.csv', index=False)
    
    fig, ax = plt.subplots(1, 1, figsize=(10, 40))
    sns.barplot(x='importance', y='features', data=fi_df.iloc[:30], ax=ax)
    logger.info(fi_df[['features', 'importance']].iloc[:50].to_markdown())

# %% [markdown]
# # Submit

# %%
if MODE == 'INFERENCE':
    """
    used for inference kernel only
    """
    y_preds = np.zeros(len(test_book_df))
    files = glob.glob(f'{MODEL_DIR}/*model*.pkl')
    assert len(files) > 0
    for i, f in enumerate(files):
        model = joblib.load(f)
        y_preds += model.predict(test_book_df[features])
    y_preds /= (i+1)
    
test_book_df[target] = y_preds

# %%
# test
test_book_df[target] = y_preds

# save the submit file
sub = test_book_df[['row_id', target]]
sub.to_csv('submission.csv',index = False)

logger.info('submitted!')
sub.head()
